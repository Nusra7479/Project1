# %%
import pandas as pd

data = pd.read_table('..\data.tsv')
data.sort_values('numVotes').reset_index()
# Out:
#           index     tconst  averageRating  numVotes
# 0        386963  tt0824566            6.0         5
# 1        740850  tt2818988            9.8         5
# 2        494675  tt1146651            6.8         5
# 3        200872  tt0363377            3.8         5
# 4        601419  tt1612809            7.6         5
# ...         ...        ...            ...       ...
# 1070313   81204  tt0110912            8.9   1780433
# 1070314   97642  tt0137523            8.8   1807697
# 1070315  558734  tt1375666            8.8   2003263
# 1070316  244683  tt0468569            9.0   2242051
# 1070317   81420  tt0111161            9.3   2279223
#
# [1070318 rows x 4 columns]

# %%
data.tconst.duplicated().sum()
# Out:
# 0

# %%
find500 = data.loc[data['numVotes'] == 500]
find500
# Out:
#             tconst  averageRating  numVotes
# 3595     tt0013674            7.0       500
# 9018     tt0024561            6.8       500
# 11826    tt0028277            7.7       500
# 22779    tt0041956            6.5       500
# 27186    tt0047361            7.3       500
# ...            ...            ...       ...
# 1043265  tt8960572            6.0       500
# 1059269  tt9454484            8.7       500
# 1062934  tt9614612            7.7       500
# 1064691  tt9680914            7.1       500
# 1069708  tt9895050            9.0       500
#
# [110 rows x 3 columns]

# %%
find500['averageRating'].mean()
# Out:
# 6.731818181818184

# %%
rangeQ = data[data['numVotes'].between(30000, 40000, inclusive="both")]
rangeQ
# Out:
#             tconst  averageRating  numVotes
# 4090     tt0015324            8.2     39659
# 10652    tt0026778            7.9     30034
# 12340    tt0028950            8.1     33182
# 16554    tt0034248            7.4     31674
# 19136    tt0037382            7.8     30254
# ...            ...            ...       ...
# 1051134  tt9166678            9.5     39561
# 1058220  tt9412098            7.2     34985
# 1059042  tt9446688            7.6     34489
# 1062871  tt9612516            6.8     39085
# 1064673  tt9680440            7.8     34564
#
# [953 rows x 3 columns]

# %%
find1000=data.loc[data['numVotes'] == 1000]
find1000
# Out:
#             tconst  averageRating  numVotes
# 16668    tt0034386            6.5      1000
# 18105    tt0036135            6.6      1000
# 25195    tt0044905            6.8      1000
# 28669    tt0049131            7.5      1000
# 33562    tt0054854            7.2      1000
# 51213    tt0075391            6.1      1000
# 57319    tt0082516            5.8      1000
# 73636    tt0101692            6.6      1000
# 88264    tt0119623            6.0      1000
# 146267   tt0240292            8.1      1000
# 170176   tt0290637            7.1      1000
# 209141   tt0381842            6.4      1000
# 218660   tt0402764            6.2      1000
# 231085   tt0433028            6.2      1000
# 232550   tt0436727            6.4      1000
# 240098   tt0456012            7.7      1000
# 250822   tt0483437            7.5      1000
# 282435   tt0558720            8.6      1000
# 288355   tt0572185            7.0      1000
# 288376   tt0572206            7.0      1000
# 347403   tt0709212            7.7      1000
# 351537   tt0720089            8.5      1000
# 356003   tt0734605            7.6      1000
# 376922   tt0793708            8.7      1000
# 403781   tt0877112            8.1      1000
# 445923  tt10299836            8.6      1000
# 464032  tt10717964            8.7      1000
# 502560   tt1170405            4.4      1000
# 507036   tt1181919            6.6      1000
# 540811   tt1291170            7.0      1000
# 575915   tt1473105            7.1      1000
# 585314   tt1523939            5.1      1000
# 604206   tt1629336            8.5      1000
# 677051   tt2120780            7.8      1000
# 762256   tt3183264            7.6      1000
# 770059   tt3303446            6.6      1000
# 791713   tt3638298            7.3      1000
# 821986   tt4168910            8.5      1000
# 905482   tt5719564            8.8      1000
# 938561   tt6303292            9.0      1000
# 993530   tt7550952            5.8      1000
# 996259   tt7613412            8.2      1000

# %%
print("------------Experiment 3-------------")
print("Num Records: \t", find500.shape[0])
print("Min NumVotes: \t",find500['numVotes'].min())
print("Max NumVotes: \t",find500['numVotes'].max())
print("Duplicates: \t", find500.numVotes.duplicated().sum())
print("avg Rating: \t", find500['averageRating'].mean())

print("------------Experiment 4-------------")
print("Num Records: \t", rangeQ.shape[0])
print("Min NumVotes: \t",rangeQ['numVotes'].min())
print("Max NumVotes: \t",rangeQ['numVotes'].max())
print("Duplicates: \t", rangeQ.numVotes.duplicated().sum())
print("avg Rating: \t", rangeQ['averageRating'].mean())

print("------------Experiment 5-------------")
print("Num Records: \t", find1000.shape[0])
# Out:
# ------------Experiment 3-------------
# Num Records: 	 110
# Min NumVotes: 	 500
# Max NumVotes: 	 500
# Duplicates: 	 109
# avg Rating: 	 6.731818181818184
# ------------Experiment 4-------------
# Num Records: 	 953
# Min NumVotes: 	 30022
# Max NumVotes: 	 39996
# Duplicates: 	 52
# avg Rating: 	 6.727911857292764
# ------------Experiment 5-------------
# Num Records: 	 42

# %%
rangeQ['averageRating'].mean()
# Out:
# 6.727911857292764
